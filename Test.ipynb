# %%
import dataRetrieval

# %%
sectors = dataRetrieval.getSectorData()

# %%
sectors
# Out:
#                         Rank A: Real-Time Performance  \
# Energy                                        -0.0347
# Utilities                                     -0.0253
# Industrials                                   -0.0214
# Financials                                    -0.0201
# Materials                                     -0.0099
# Consumer Staples                              -0.0095
# Real Estate                                   -0.0095
# Health Care                                   -0.0039
# Communication Services                         0.0004
# Consumer Discretionary                         0.0044
# Information Technology                         0.0047
#
#                         Rank B: Day Performance  Rank C: Day Performance  \
# Energy                                   0.0432                   0.1840
# Utilities                                0.0264                   0.0395
# Industrials                              0.0197                   0.1248
# ...

# %%
topSectors = dataRetrieval.findBestSector()

# %%
topSectors
# Out:
#              Rank A: Real-Time Performance  Rank B: Day Performance  \
# Energy                             -0.0347                   0.0432
# Utilities                          -0.0253                   0.0264
# Industrials                        -0.0214                   0.0197
#
#              Rank C: Day Performance  Rank D: Month Performance  \
# Energy                        0.1840                     0.2427
# Utilities                     0.0395                     0.1354
# Industrials                   0.1248                     0.2353
#
#              Rank E: Month Performance  \
# Energy                          0.1017
# Utilities                      -0.0633
# Industrials                     0.0562
#
#              Rank F: Year-to-Date (YTD) Performance  Rank G: Year Performance  \
# Energy                                      -0.2309                   -0.2193
# Utilities                                   -0.0336                    0.0492
# ...
